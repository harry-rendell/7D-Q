# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
sys.path.insert(0, os.path.join(os.getcwd(), ".."))
from module.config import cfg
from module.classes.analysis import analysis
from module.preprocessing import data_io

# %%
OBJ = 'qsos'
BANDS = 'r'
# BANDS = 'gri'
dr = analysis(OBJ, BANDS)

# %% [markdown]
# ### Read in 1000 rows from each file in parallel using 4 cores and concatenate the result

# %%
dr.read_merged_photometry(nrows=10, fnames=None, ncores=4, i=None)
dr.df
# Out:
# Number of objects removed with single observation: 3
#        band        mag    magerr           mjd        mjd_rf  sid
# uid
# 1         r  22.071905  0.115390  54741.371094  16543.176517    5
# 1         r  21.584364  0.179572  55806.593750  16865.093306    7
# 1         r  21.763350  0.176923  56247.320312  16998.283564    7
# 5001      r  21.275259  0.046779  52909.375000  15252.053906    5
# 5001      r  21.582647  0.082283  54764.335938  15786.778881    5
# ...     ...        ...       ...           ...           ...  ...
# 525001    r  20.817167  0.038546  54769.253906  23106.630688    5
# 525001    r  20.631010  0.067633  55088.488281  23241.312654    7
# 525001    r  20.694975  0.095520  55094.515625  23243.855533    7
# 525001    r  20.700666  0.084105  55098.515625  23245.543095    7
# 525001    r  20.576838  0.081879  55102.468750  23247.210882    7
#
# [403 rows x 6 columns]

# %% [markdown]
# ### Read in all rows (nrows=None) of the specified files using 2 cores and concatenate the result

# %%
dr.read_merged_photometry(ncores=2, nrows=None, fnames=['lc_000000_005000.csv','lc_020001_025000.csv','lc_055001_060000.csv'])
dr.df
# Out:
# Number of objects removed with single observation: 131
#       band        mag    magerr           mjd        mjd_rf  sid
# uid
# 1        r  22.071905  0.115390  54741.371094  16543.176517    5
# 1        r  21.584364  0.179572  55806.593750  16865.093306    7
# 1        r  21.763350  0.176923  56247.320312  16998.283564    7
# 2        r  21.339039  0.071079  54747.351562  17642.677779    5
# 2        r  21.089470  0.093216  55452.488281  17869.912514    7
# ...    ...        ...       ...           ...           ...  ...
# 60000    r  19.072556  0.053037  58775.289062  27600.739533   11
# 60000    r  19.144777  0.067355  59271.125000  27833.582940   11
# 60000    r  19.155491  0.068248  59272.128906  27834.054372   11
# 60000    r  19.024017  0.061514  59273.128906  27834.523970   11
# 60000    r  19.048328  0.062858  59275.128906  27835.463165   11
#
# [1807850 rows x 6 columns]

# %% [markdown]
# ### Read in the 10th file only using single core

# %%
dr.read_merged_photometry(i=10)
dr.df
# Out:
# Number of objects removed with single observation: 30
#       band        mag    magerr           mjd        mjd_rf  sid
# uid
# 50001    r  20.804918  0.058148  51081.335938  20791.388755    5
# 50001    r  20.907183  0.058027  51132.195312  20812.089800    5
# 50001    r  20.895473  0.051564  51136.183594  20813.713131    5
# 50001    r  20.900118  0.052941  51819.406250  21091.801939    5
# 50001    r  20.963671  0.063033  52282.105469  21280.132161    5
# ...    ...        ...       ...           ...           ...  ...
# 55000    r  19.839527  0.118448  59913.253906  25969.075422   11
# 55000    r  19.723705  0.110135  59922.207031  25972.956106   11
# 55000    r  19.617342  0.102244  59930.277344  25976.454139   11
# 55000    r  19.905466  0.123390  59933.148438  25977.698599   11
# 55000    r  19.895069  0.122422  59936.164062  25979.005705   11
#
# [616298 rows x 6 columns]

# %% [markdown]
# ### Read in all rows (nrows=None) of the specified files using 2 cores and concatenate the result

# %%
dr.df[dr.df['band'] == 'r']
# Out:
#       band        mag    magerr           mjd        mjd_rf  sid
# uid
# 50001    r  20.804918  0.058148  51081.335938  20791.388755    5
# 50001    r  20.907183  0.058027  51132.195312  20812.089800    5
# 50001    r  20.895473  0.051564  51136.183594  20813.713131    5
# 50001    r  20.900118  0.052941  51819.406250  21091.801939    5
# 50001    r  20.963671  0.063033  52282.105469  21280.132161    5
# ...    ...        ...       ...           ...           ...  ...
# 55000    r  19.839527  0.118448  59913.253906  25969.075422   11
# 55000    r  19.723705  0.110135  59922.207031  25972.956106   11
# 55000    r  19.617342  0.102244  59930.277344  25976.454139   11
# 55000    r  19.905466  0.123390  59933.148438  25977.698599   11
# 55000    r  19.895069  0.122422  59936.164062  25979.005705   11
#
# [616298 rows x 6 columns]

# %% [markdown]
# # Plot some lightcurves

# %%
dr.plot_series(uids=[50001,55000], bands='gri')
# Out:
# (<Figure size 2500x600 with 2 Axes>,
#  array([<Axes: xlabel='MJD', ylabel='mag'>,
#         <Axes: xlabel='MJD', ylabel='mag'>], dtype=object))

# %% [markdown]
# ### Look up object uid=525008 in SDSS

# %%
dr.sdss_quick_look(525008)
# Out:
# https://skyserver.sdss.org/dr18/VisualTools/quickobj?ra=359.4738673957129&dec=-3.072119888814848
